# %% [markdown]
# # Squamata Batch Replace ScienceBase XML
# A Jupyter Notebook used to download multiple XML Metadata files from ScicenceBase, make a change to this XML file and re-upload.
#
# Uses code examples found in autoSB.py, https://github.com/pbrown-usgs/science-base-automationMT/blob/first-branch/autoSB.py
#
# **Version 1.1**
#  - Update child metadata based upon a known directory and file structure
#  - test using Silverton Caldera AMT, this test had all the replacement files in one directory

# %%
# Load required Libraries
import sys
import os
from lxml import etree
import pandas as pd
import numpy as np
import json
import sys
import sciencebasepy as pysb
import glob

#Create Function that allows one to implement markdown display when printing
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))

# %%
#Set Data Paths - perhaps we'll get a user form to do this some day?
dataPath = r"C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata" #The 'r' signifies a string literal. Use for paths.

# %%
#Now List the xml files
#Look for EDI file to load
xmlListFullPath = glob.glob(os.path.join(dataPath, '*.xml'),  recursive=True)
xmlListFullPath
#xmlPath = xmlList[0]
#ediList
#print ('XML File Path:\n' + xmlPath)
#ediPathArray = ediPath.split('\\')
#ediFile = str(ediPathArray[len(ediPathArray)-1])
#print ('EDI File:\n' + ediFile)
#EdiFileName = ediFile
#ediPathArray
# Out:
# ['C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMT.shp.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTAG01.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTAG02.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTAG03.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTAG04.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTAG05.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTAG06.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTEG06.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTEG07.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTEG08.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTKM01.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTKM02.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTKM03.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTKM04.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTKM05.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTMB06.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTMB07.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTMB08.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTMB09.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTMC01.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTMC02.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTSF01.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTSF02.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTSF03.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTSF04.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTSF05.xml',
#  'C:\\CurrentWork\\DataReleases\\SilvertonAMT_SB-Batch-Upload-Test\\Metadata\\USA-Colorado-Silverton_Caldera-2019-AMTSF06.xml']

# %%
#Based on the above let's make a list of file names to overright with:
#Create file pointer array:

xmlFileNameArray = []
i=0
for item in xmlListFullPath:
 splitPath = xmlListFullPath[i].split('\\')
 xmlFileNameArray.append(splitPath[len(splitPath) - 1])
 i= i+1

#Print array
for i in range(len(xmlListFullPath)): 
 print (xmlListFullPath[i])
 print (xmlFileNameArray[i])
# Out:
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMT.shp.xml
# USA-Colorado-Silverton_Caldera-2019-AMT.shp.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG01.xml
# USA-Colorado-Silverton_Caldera-2019-AMTAG01.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG02.xml
# USA-Colorado-Silverton_Caldera-2019-AMTAG02.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG03.xml
# USA-Colorado-Silverton_Caldera-2019-AMTAG03.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG04.xml
# USA-Colorado-Silverton_Caldera-2019-AMTAG04.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG05.xml
# USA-Colorado-Silverton_Caldera-2019-AMTAG05.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG06.xml
# USA-Colorado-Silverton_Caldera-2019-AMTAG06.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTEG06.xml
# USA-Colorado-Silverton_Caldera-2019-AMTEG06.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTEG07.xml
# USA-Colorado-Silverton_Caldera-2019-AMTEG07.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTEG08.xml
# USA-Colorado-Silverton_Caldera-2019-AMTEG08.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTKM01.xml
# USA-Colorado-Silverton_Caldera-2019-AMTKM01.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTKM02.xml
# USA-Colorado-Silverton_Caldera-2019-AMTKM02.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTKM03.xml
# USA-Colorado-Silverton_Caldera-2019-AMTKM03.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTKM04.xml
# USA-Colorado-Silverton_Caldera-2019-AMTKM04.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTKM05.xml
# USA-Colorado-Silverton_Caldera-2019-AMTKM05.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMB06.xml
# USA-Colorado-Silverton_Caldera-2019-AMTMB06.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMB07.xml
# USA-Colorado-Silverton_Caldera-2019-AMTMB07.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMB08.xml
# USA-Colorado-Silverton_Caldera-2019-AMTMB08.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMB09.xml
# USA-Colorado-Silverton_Caldera-2019-AMTMB09.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMC01.xml
# USA-Colorado-Silverton_Caldera-2019-AMTMC01.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMC02.xml
# USA-Colorado-Silverton_Caldera-2019-AMTMC02.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF01.xml
# USA-Colorado-Silverton_Caldera-2019-AMTSF01.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF02.xml
# USA-Colorado-Silverton_Caldera-2019-AMTSF02.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF03.xml
# USA-Colorado-Silverton_Caldera-2019-AMTSF03.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF04.xml
# USA-Colorado-Silverton_Caldera-2019-AMTSF04.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF05.xml
# USA-Colorado-Silverton_Caldera-2019-AMTSF05.xml
# C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF06.xml
# USA-Colorado-Silverton_Caldera-2019-AMTSF06.xml

# %%
#Login to ScienceBase
sb = pysb.SbSession()
username = input("Username:  ")
sb.loginc(str(username))

#Check to see if login is successful
sb.is_logged_in()

#Get the ScienceBase Login session info
sb.get_session_info()
# Out:
# Username:  pbrown@usgs.gov
# ········
# {'fullDisplayName': 'Philip J Brown II [pbrown@usgs.gov]',
#  'isLoggedIn': True,
#  'jossoSessionId': 'DF4B533389A0803492E260B2C1C561D8',
#  'displayName': 'Philip J Brown II',
#  'email': 'pbrown@usgs.gov',
#  'username': 'pbrown@usgs.gov'}

# %%
#Now lets check all the child items.

catNum = '5e6a6d16e4b01d509260e769' #Make sure one has the correct catalog number
item_json = sb.get_item(catNum)

#print ("Public Item: \n\t" + str(item_json))
print(json.dumps(item_json, indent=2, sort_keys=True))
# Out:
# {
#   "body": "This dataset includes audiomagnetotelluric (AMT) sounding data collected in July 2019 in the Silverton Caldera complex, Colorado, in the Southern Rocky Mountain Volcanic Field, by the U.S. Geological Survey (USGS). Along with geologic mapping, airborne magnetics, airborne electromagnetics, and magnetotellurics, the USGS collected AMT data at 26 sites along five profiles ranging from 2 to 5 kilometers in length: across Red Mountain of the Silverton caldera, within the caldera in Eureka Graben, across the south-eastern margin of the caldera along Arrastra Gulch, across the southern margin of the caldera along the western margin of Kendall Mountain, and across the south-western margin of the caldera along South Fork Mineral Creek.",
#   "browseCategories": [
#     "Data Release - In Progress",
#     "Data"
#   ],
#   "browseTypes": [
#     "Shapefile",
#     "Downloadable",
#     "Map Service",
#     "OGC WMS Layer",
#     "OGC WFS Layer"
#   ],
#   "citation": "Reitman, J., Rodriguez, B.D., Brown, P.J., and Yager, D.B., 2021, Audiomagnetotelluric sounding data in the Silverton Caldera complex, Colorado, 2019: U.S. Geological Survey data release, https://doi.org/10.5066/P9F68AQP.",
#   "contacts": [
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "jreitman@usgs.gov",
#       "firstName": "James",
#       "jobTitle": "Chemist",
#       "lastName": "Reitman",
#       "name": "James Reitman",
#       "oldPartyId": 58796,
#       "onlineResource": "https://usgs.gov/staff-profiles/james-reitman",
#       "orcId": "0000-0003-3551-9884",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "primaryLocation": {
#         "building": "DFC Bldg 20",
#         "buildingCode": "KAC",
#         "faxPhone": "3032363200",
#         "mailAddress": {},
#         "name": "James Reitman/GD/VOL/USGS/DOI - Primary Location",
#         "officePhone": "3032361300",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Point of Contact"
#     },
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "jreitman@usgs.gov",
#       "firstName": "James",
#       "jobTitle": "Chemist",
#       "lastName": "Reitman",
#       "name": "James Reitman",
#       "oldPartyId": 58796,
#       "onlineResource": "https://usgs.gov/staff-profiles/james-reitman",
#       "orcId": "0000-0003-3551-9884",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "primaryLocation": {
#         "building": "DFC Bldg 20",
#         "buildingCode": "KAC",
#         "faxPhone": "3032363200",
#         "mailAddress": {},
#         "name": "James Reitman/GD/VOL/USGS/DOI - Primary Location",
#         "officePhone": "3032361300",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Originator"
#     },
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "brod@usgs.gov",
#       "firstName": "Brian",
#       "jobTitle": "Volunteer",
#       "lastName": "Rodriguez",
#       "middleName": "D",
#       "name": "Brian D Rodriguez",
#       "oldPartyId": 8727,
#       "orcId": "0000-0002-2263-611X",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "personalTitle": "Mr.",
#       "primaryLocation": {
#         "buildingCode": "KAC",
#         "mailAddress": {},
#         "name": "Brian D Rodriguez/GD/USGS/DOI - Primary Location",
#         "officePhone": "3032361361",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Originator"
#     },
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "pbrown@usgs.gov",
#       "firstName": "Philip",
#       "jobTitle": "Geophysicist",
#       "lastName": "Brown II",
#       "middleName": "J",
#       "name": "Philip J Brown II",
#       "oldPartyId": 1233,
#       "onlineResource": "https://usgs.gov/staff-profiles/philip-j-brown",
#       "orcId": "0000-0002-2415-7462",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "primaryLocation": {
#         "building": "DFC Bldg 20",
#         "buildingCode": "KAC",
#         "faxPhone": "3032361425",
#         "mailAddress": {},
#         "name": "Philip J Brown II/GD/USGS/DOI - Primary Location",
#         "officePhone": "3032361310",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Originator"
#     },
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "pbrown@usgs.gov",
#       "firstName": "Philip",
#       "jobTitle": "Geophysicist",
#       "lastName": "Brown II",
#       "middleName": "J",
#       "name": "Philip J Brown II",
#       "oldPartyId": 1233,
#       "onlineResource": "https://usgs.gov/staff-profiles/philip-j-brown",
#       "orcId": "0000-0002-2415-7462",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "primaryLocation": {
#         "building": "DFC Bldg 20",
#         "buildingCode": "KAC",
#         "faxPhone": "3032361425",
#         "mailAddress": {},
#         "name": "Philip J Brown II/GD/USGS/DOI - Primary Location",
#         "officePhone": "3032361310",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Metadata Contact"
#     },
#     {
#       "active": true,
#       "aliases": [
#         "{\"name\":\"Geological Survey (U.S.)\"}",
#         "{\"name\":\"USGS\"}",
#         "{\"name\":\"U.S. GEOLOGICAL SURVEY\"}"
#       ],
#       "contactType": "organization",
#       "fbmsCodes": [
#         "GG00000000"
#       ],
#       "logoUrl": "http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/USGSLogo.gif",
#       "name": "U.S. Geological Survey",
#       "oldPartyId": 18139,
#       "onlineResource": "http://www.usgs.gov/",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "name": "U.S. Geological Survey - Location",
#         "streetAddress": {}
#       },
#       "smallLogoUrl": "http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/USGSLogo.gif",
#       "type": "Publisher"
#     },
#     {
#       "contactType": "organization",
#       "email": "sciencebase@usgs.gov",
#       "name": "U.S. Geological Survey - ScienceBase",
#       "oldPartyId": 70157,
#       "onlineResource": "https://www.sciencebase.gov",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {
#           "city": "Denver",
#           "country": "United States",
#           "line1": "Denver Federal Center",
#           "line2": "Building 810",
#           "mailStopCode": "302",
#           "state": "CO",
#           "zip": "80225"
#         },
#         "name": "U.S. Geological Survey - ScienceBase - Location",
#         "officePhone": "18882758747",
#         "streetAddress": {}
#       },
#       "type": "Distributor"
#     },
#     {
#       "aliases": [
#         "{\"name\":\"GGGSC\"}"
#       ],
#       "contactType": "organization",
#       "name": "Geology, Geophysics, and Geochemistry Science Center",
#       "oldPartyId": 76255,
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "name": "Geology, Geophysics, and Geochemistry Science Center - Location",
#         "streetAddress": {}
#       },
#       "type": "SDC Data Owner"
#     },
#     {
#       "active": true,
#       "contactType": "organization",
#       "name": "Energy and Minerals",
#       "oldPartyId": 64232,
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "name": "Energy and Minerals Mission Area - Location",
#         "streetAddress": {}
#       },
#       "type": "USGS Mission Area"
#     },
#     {
#       "contactType": "person",
#       "email": "gs_gggsc_dm_team@usgs.gov",
#       "firstName": "GS  GGGSC",
#       "lastName": "DM Team",
#       "name": "GS GGGSC DM Team",
#       "oldPartyId": 72934,
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "name": "CN=GS CMERSC CGGSC DM Team,OU=Shared Mailboxes,OU=Messaging,DC=gs,DC=doi,DC=net - Primary Location",
#         "streetAddress": {}
#       },
#       "type": "Metadata Contact"
#     },
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "dyager@usgs.gov",
#       "firstName": "Douglas",
#       "jobTitle": "Geologist",
#       "lastName": "Yager",
#       "middleName": "B",
#       "name": "Douglas B Yager",
#       "oldPartyId": 11519,
#       "onlineResource": "https://usgs.gov/staff-profiles/douglas-b-yager",
#       "orcId": "0000-0001-5074-4022",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "primaryLocation": {
#         "building": "DFC Bldg 20",
#         "buildingCode": "KAC",
#         "faxPhone": "3032363200",
#         "mailAddress": {},
#         "name": "Douglas B Yager/GD/USGS/DOI - Primary Location",
#         "officePhone": "3032362487",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Originator"
#     }
#   ],
#   "dates": [
#     {
#       "dateString": "2020",
#       "label": "Publication Date",
#       "type": "Publication"
#     },
#     {
#       "dateString": "2019-07-16",
#       "label": "",
#       "type": "Start"
#     },
#     {
#       "dateString": "2019-07-29",
#       "label": "",
#       "type": "End"
#     }
#   ],
#   "distributionLinks": [
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "KML Service",
#       "type": "kml",
#       "typeLabel": "KML Download",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/5e6a6d16e4b01d509260e769?mode=download&request=kml&service=wms&layers=USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase WMS Service",
#       "type": "serviceCapabilitiesUrl",
#       "typeLabel": "OGC Service Capabilities URL",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/5e6a6d16e4b01d509260e769?service=wms&request=getcapabilities&version=1.3.0"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase WFS Service",
#       "type": "serviceCapabilitiesUrl",
#       "typeLabel": "OGC Service Capabilities URL",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/5e6a6d16e4b01d509260e769?service=wfs&request=getcapabilities&version=1.0.0"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase Collection JSON",
#       "type": "repo",
#       "typeLabel": "ScienceBase Repository",
#       "uri": "https://www.sciencebase.gov/catalog/items?parentId=5e6a6d16e4b01d509260e769&format=json"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase Collection ATOM",
#       "type": "repo",
#       "typeLabel": "ScienceBase Repository",
#       "uri": "https://www.sciencebase.gov/catalog/items?parentId=5e6a6d16e4b01d509260e769&format=atom"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase Collection CSV",
#       "type": "repo",
#       "typeLabel": "ScienceBase Repository",
#       "uri": "https://www.sciencebase.gov/catalog/items?parentId=5e6a6d16e4b01d509260e769&format=csv"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase OAI PMH Service",
#       "type": "oai-pmh",
#       "typeLabel": "OAI-PMH",
#       "uri": "https://www.sciencebase.gov/catalog/oai-pmh?verb=ListRecords&metadataPrefix=fgdc-orig&set=5e6a6d16e4b01d509260e769"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase CSW Service",
#       "type": "csw",
#       "typeLabel": "",
#       "uri": "https://www.sciencebase.gov/catalog/item/5e6a6d16e4b01d509260e769/csw?service=CSW&version=2.0.2&request=GetRecords"
#     },
#     {
#       "files": [
#         {
#           "contentType": "text/plain",
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations/USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.cpg",
#           "size": 5,
#           "title": ""
#         },
#         {
#           "contentType": "text/plain",
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations/USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.dbf",
#           "size": 15962,
#           "title": ""
#         },
#         {
#           "contentType": "text/plain",
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations/USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.prj",
#           "size": 145,
#           "title": ""
#         },
#         {
#           "contentType": "x-gis/x-shapefile",
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations/USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.sbn",
#           "size": 404,
#           "title": ""
#         },
#         {
#           "contentType": "x-gis/x-shapefile",
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations/USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.sbx",
#           "size": 140,
#           "title": ""
#         },
#         {
#           "contentType": "x-gis/x-shapefile",
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations/USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.shp",
#           "size": 828,
#           "title": ""
#         },
#         {
#           "contentType": "x-gis/x-shapefile",
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations/USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.shx",
#           "size": 308,
#           "title": ""
#         },
#         {
#           "contentType": "application/fgdc+xml",
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT.shp.xml",
#           "size": 22338,
#           "title": ""
#         }
#       ],
#       "name": "Audiomagnetotel.zip",
#       "rel": "alternate",
#       "title": "Download Attached Files",
#       "type": "downloadLink",
#       "typeLabel": "Download Link",
#       "uri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769"
#     }
#   ],
#   "facets": [
#     {
#       "boundingBox": {
#         "maxX": -107.60406,
#         "maxY": 37.90509,
#         "minX": -107.75651,
#         "minY": 37.77665
#       },
#       "className": "gov.sciencebase.catalog.item.facet.ShapefileFacet",
#       "facetName": "Shapefile",
#       "files": [
#         {
#           "bucket": null,
#           "checksum": null,
#           "contentEncoding": null,
#           "contentType": "text/plain",
#           "cuid": null,
#           "dateUploaded": "2020-06-10T12:25:06Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__f9%2F19%2F7d%2Ff9197d6f0dd217184cea3e6a50c83215e7bd7c1f",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.cpg",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__f9/19/7d/f9197d6f0dd217184cea3e6a50c83215e7bd7c1f",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 5,
#           "title": "",
#           "uploadedBy": "brod@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__f9%2F19%2F7d%2Ff9197d6f0dd217184cea3e6a50c83215e7bd7c1f",
#           "useForPreview": false,
#           "viewUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__f9%2F19%2F7d%2Ff9197d6f0dd217184cea3e6a50c83215e7bd7c1f&allowOpen=true"
#         },
#         {
#           "bucket": null,
#           "checksum": null,
#           "contentEncoding": null,
#           "contentType": "text/plain",
#           "cuid": null,
#           "dateUploaded": "2020-06-10T12:25:06Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__6f%2F29%2Fb2%2F6f29b27654f8aaad191cfb20c42344bdae0291cb",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.dbf",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__6f/29/b2/6f29b27654f8aaad191cfb20c42344bdae0291cb",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 15962,
#           "title": "",
#           "uploadedBy": "brod@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__6f%2F29%2Fb2%2F6f29b27654f8aaad191cfb20c42344bdae0291cb",
#           "useForPreview": false,
#           "viewUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__6f%2F29%2Fb2%2F6f29b27654f8aaad191cfb20c42344bdae0291cb&allowOpen=true"
#         },
#         {
#           "bucket": null,
#           "checksum": null,
#           "contentEncoding": null,
#           "contentType": "text/plain",
#           "cuid": null,
#           "dateUploaded": "2020-06-10T12:25:06Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__b2%2F31%2F82%2Fb2318249c7afc38771488af9c6433161c4de8f33",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.prj",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__b2/31/82/b2318249c7afc38771488af9c6433161c4de8f33",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 145,
#           "title": "",
#           "uploadedBy": "brod@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__b2%2F31%2F82%2Fb2318249c7afc38771488af9c6433161c4de8f33",
#           "useForPreview": false,
#           "viewUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__b2%2F31%2F82%2Fb2318249c7afc38771488af9c6433161c4de8f33&allowOpen=true"
#         },
#         {
#           "bucket": null,
#           "checksum": null,
#           "contentEncoding": null,
#           "contentType": "x-gis/x-shapefile",
#           "cuid": null,
#           "dateUploaded": "2020-06-10T12:25:06Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__49%2Ff9%2Ff4%2F49f9f44c05ba43ae08b5782583bbe0386abd0dc7",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.sbn",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__49/f9/f4/49f9f44c05ba43ae08b5782583bbe0386abd0dc7",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 404,
#           "title": "",
#           "uploadedBy": "brod@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__49%2Ff9%2Ff4%2F49f9f44c05ba43ae08b5782583bbe0386abd0dc7",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": null,
#           "contentEncoding": null,
#           "contentType": "x-gis/x-shapefile",
#           "cuid": null,
#           "dateUploaded": "2020-06-10T12:25:06Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__5c%2Fce%2F47%2F5cce479497cdbb15d87e7001e7e5bfb52742cae0",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.sbx",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__5c/ce/47/5cce479497cdbb15d87e7001e7e5bfb52742cae0",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 140,
#           "title": "",
#           "uploadedBy": "brod@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__5c%2Fce%2F47%2F5cce479497cdbb15d87e7001e7e5bfb52742cae0",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": null,
#           "contentEncoding": null,
#           "contentType": "x-gis/x-shapefile",
#           "cuid": null,
#           "dateUploaded": "2020-06-10T12:25:06Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__61%2F2d%2F6b%2F612d6be3abb275d0508e69d618c54a499fe6b124",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.shp",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__61/2d/6b/612d6be3abb275d0508e69d618c54a499fe6b124",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 828,
#           "title": "",
#           "uploadedBy": "brod@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__61%2F2d%2F6b%2F612d6be3abb275d0508e69d618c54a499fe6b124",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": null,
#           "contentEncoding": null,
#           "contentType": "x-gis/x-shapefile",
#           "cuid": null,
#           "dateUploaded": "2020-06-10T12:25:06Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__3a%2F55%2F66%2F3a556612024975a243c872e2e92125be2b6368b5",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations.shx",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__3a/55/66/3a556612024975a243c872e2e92125be2b6368b5",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 308,
#           "title": "",
#           "uploadedBy": "brod@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__3a%2F55%2F66%2F3a556612024975a243c872e2e92125be2b6368b5",
#           "useForPreview": false
#         }
#       ],
#       "geometryType": "Point",
#       "name": "USA-Colorado-Silverton_Caldera-2019-AMT_StationLocations",
#       "nativeCrs": "EPSG:4326"
#     }
#   ],
#   "files": [
#     {
#       "bucket": null,
#       "checksum": {
#         "type": "MD5",
#         "value": "da1cd22ab857f0e80101d80dbc4e47f4"
#       },
#       "contentEncoding": null,
#       "contentType": "application/fgdc+xml",
#       "cuid": null,
#       "dateUploaded": "2021-02-02T23:39:08Z",
#       "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__b1%2F50%2F8e%2Fb1508ea219f7b3668c9af6755d9054119c9390e3",
#       "imageHeight": null,
#       "imageWidth": null,
#       "key": null,
#       "metadataHtmlViewUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__b1%2F50%2F8e%2Fb1508ea219f7b3668c9af6755d9054119c9390e3&transform=1",
#       "name": "USA-Colorado-Silverton_Caldera-2019-AMT.shp.xml",
#       "node": null,
#       "originalMetadata": true,
#       "pathOnDisk": "__disk__b1/50/8e/b1508ea219f7b3668c9af6755d9054119c9390e3",
#       "processToken": null,
#       "processed": false,
#       "published": null,
#       "s3Object": null,
#       "size": 22338,
#       "title": "",
#       "uploadedBy": "mgoldman@usgs.gov",
#       "url": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__b1%2F50%2F8e%2Fb1508ea219f7b3668c9af6755d9054119c9390e3",
#       "useForPreview": false
#     }
#   ],
#   "hasChildren": true,
#   "id": "5e6a6d16e4b01d509260e769",
#   "identifiers": [
#     {
#       "key": "IP-117537",
#       "scheme": "https://www.sciencebase.gov/vocab/category/item/identifier",
#       "type": "IPDS"
#     },
#     {
#       "key": "doi:10.5066/P9F68AQP",
#       "scheme": "https://www.sciencebase.gov/vocab/category/item/identifier",
#       "type": "DOI"
#     },
#     {
#       "key": "Geology, Geophysics, and Geochemistry Science Center",
#       "scheme": "https://www.sciencebase.gov/vocab/category/item/identifier",
#       "type": "USGS_ScienceCenter"
#     },
#     {
#       "key": "Energy and Minerals",
#       "scheme": "https://www.sciencebase.gov/vocab/category/item/identifier",
#       "type": "USGS_MissionArea"
#     },
#     {
#       "key": "Environmental Health, Geophysics, Mineral Resources, Volcanology, Water Quality",
#       "scheme": "https://www.sciencebase.gov/vocab/category/item/identifier",
#       "type": "USGS_keywords"
#     }
#   ],
#   "link": {
#     "rel": "self",
#     "url": "https://www.sciencebase.gov/catalog/item/5e6a6d16e4b01d509260e769"
#   },
#   "locked": false,
#   "maintenanceUpdateFrequency": "Not planned",
#   "parentId": "5873af5ee4b0a829a31e312e",
#   "permissions": {
#     "read": {
#       "acl": [
#         "ROLE:BAO",
#         "ROLE:CGGSC_CMERSC_Data_Managers",
#         "USER:abern@usgs.gov",
#         "USER:blburton@usgs.gov",
#         "USER:brod@usgs.gov",
#         "USER:ericanderson@usgs.gov",
#         "USER:jreitman@usgs.gov",
#         "USER:kzamudio@usgs.gov",
#         "USER:pbrown@usgs.gov",
#         "USER:rhorton@usgs.gov",
#         "USER:sgiles@usgs.gov"
#       ],
#       "inherited": false
#     },
#     "write": {
#       "acl": [
#         "ROLE:CGGSC_CMERSC_Data_Managers",
#         "ROLE:ScienceBase_Data_Release_Team",
#         "USER:brod@usgs.gov",
#         "USER:pbrown@usgs.gov"
#       ],
#       "inherited": false
#     }
#   },
#   "previewImage": {
#     "from": "mapPreview",
#     "original": {
#       "height": 240,
#       "size": 233064,
#       "uri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__91%2F56%2Fb7%2F9156b77796939621763b7349662524ad74a843c2",
#       "viewUri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__91%2F56%2Fb7%2F9156b77796939621763b7349662524ad74a843c2&width=360&height=240",
#       "viewUrl": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?deprecated=__use__viewUri__instead__&f=__disk__91%2F56%2Fb7%2F9156b77796939621763b7349662524ad74a843c2&width=360&height=240",
#       "width": 360
#     },
#     "thumbnail": {
#       "height": 100,
#       "uri": "https://www.sciencebase.gov/catalog/file/get/5e6a6d16e4b01d509260e769?f=__disk__91%2F56%2Fb7%2F9156b77796939621763b7349662524ad74a843c2&width=150&height=100",
#       "width": 150
#     }
#   },
#   "provenance": {
#     "createdBy": "brod@usgs.gov",
#     "dateCreated": "2020-03-12T17:10:46Z",
#     "lastUpdated": "2021-02-03T00:28:56Z",
#     "lastUpdatedBy": "mgoldman@usgs.gov"
#   },
#   "purpose": "The purpose of this data release is to provide audiomagnetotelluric (AMT) station locations and data to the public. The purpose of the survey is to help to characterize subsurface rock properties important for understanding surface water and groundwater quality issues, and also to improve knowledge of deep geologic structures that may have been conduits for hydrothermal fluids that formed mineral deposits. The study also has general applications to mineral resource assessments in other areas of the world, and to identify possible groundwater flow paths and associated geochemistry important in abandoned mine lands cleanup.",
#   "relatedItems": {
#     "link": {
#       "rel": "related",
#       "url": "https://www.sciencebase.gov/catalog/itemLinks?itemId=5e6a6d16e4b01d509260e769"
#     }
#   },
#   "spatial": {
#     "boundingBox": {
#       "maxX": -107.60406,
#       "maxY": 37.89458,
#       "minX": -107.75651,
#       "minY": 37.77665
#     }
#   },
#   "summary": "This dataset includes audiomagnetotelluric (AMT) sounding data collected in July 2019 in the Silverton Caldera complex, Colorado, in the Southern Rocky Mountain Volcanic Field, by the U.S. Geological Survey (USGS). Along with geologic mapping, airborne magnetics, airborne electromagnetics, and magnetotellurics, the USGS collected AMT data at 26 sites along five profiles ranging from 2 to 5 kilometers in length: across Red Mountain of the Silverton caldera, within the caldera in Eureka Graben, across the south-eastern margin of the caldera along Arrastra Gulch, across the southern margin of the caldera along the western margin of Kendall Mountain, and across the south-western margin of the caldera along South Fork Mineral Creek.",
#   "systemTypes": [
#     "Folder",
#     "Downloadable",
#     "Mappable"
#   ],
#   "tags": [
#     {
#       "name": "magnetic field (earth)",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "geophysics",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "GPS measurement",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "magnetotelluric surveying",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "water quality",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "mineral deposits",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "hydrothermal processes",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "mineral resources",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "abandoned mines and quarries",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "geoscientificInformation",
#       "scheme": "ISO 19115 Topic Category",
#       "type": "Theme"
#     },
#     {
#       "name": "economy",
#       "scheme": "ISO 19115 Topic Category",
#       "type": "Theme"
#     },
#     {
#       "name": "Department of the Interior",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "DOI",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "U.S. Geological Survey",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "USGS",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "Mineral Resources Program",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "MRP",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "Geology, Geophysics, and Geochemistry Science Center",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "GGGSC",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "electric field (earth)",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "impedance",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "tipper",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "apparent resistivity",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "impedance phase",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "impedance strike",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "magnetotelluric",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "MT",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "audiomagnetotelluric",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "AMT",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "sounding",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "San Juan-Silverton Caldera Complex",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "abandoned mine lands cleanup",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "Silverton",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Southern Rocky Mountain Volcanic Field",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "San Juan County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Ouray County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Animas River",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "South Fork Mineral Creek",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Red Mountain",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Arrastra Creek",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Kendall Mountain",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Eureka Graben",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Southern Rocky Mountains",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "San Juan County",
#       "scheme": "Common geographic areas",
#       "type": "Place"
#     },
#     {
#       "name": "Colorado",
#       "scheme": "Common geographic areas",
#       "type": "Place"
#     }
#   ],
#   "title": "Audiomagnetotelluric sounding data in the Silverton Caldera complex, Colorado, 2019",
#   "webLinks": [
#     {
#       "hidden": false,
#       "title": "High resolution helicopter-borne magnetic and electromagnetic survey Eureka Graben area, Colorado September 1999",
#       "uri": "https://doi.org/10.5066/F75D8R1W"
#     },
#     {
#       "hidden": false,
#       "title": "Airborne electromagnetic and magnetic survey data of the San Juan-Silverton Caldera complex, Silverton, Colorado, 2019",
#       "uri": "https://doi.org/10.5066/P98SED0J"
#     }
#   ]
# }

# %%
#Now let's get all the children catalogs
children = sb.get_child_ids(catNum)
#Print array
for i in range(len(children)): 
 print (children[i])
# Out:
# 5ee0d68b82ce7e579c708e36
# 5ee0d9fa82ce7e579c708e67
# 5ee0dcff82ce7e579c708e83
# 5ee0d4ba82ce7e579c708e31
# 5ee0d3c782ce7e579c708e2e
# 5ee0d72c82ce7e579c708e45
# 5ee0d86a82ce7e579c708e55
# 5ee0db6182ce7e579c708e74
# 5ee0d82782ce7e579c708e51
# 5ee0dd4d82ce7e579c708e85
# 5ee0d77f82ce7e579c708e48
# 5ee0da7282ce7e579c708e6b
# 5ee0db2082ce7e579c708e71
# 5ee0dd8582ce7e579c708e87
# 5ee0d8f582ce7e579c708e5e
# 5ee0daea82ce7e579c708e6f
# 5ee0dcc382ce7e579c708e7f
# 5ee0d6d182ce7e579c708e39
# 5ee0d97e82ce7e579c708e62
# 5ee0d2d482ce7e579c708e28
# 5ee0d8b882ce7e579c708e5a
# 5ee0dc8a82ce7e579c708e7a
# 5ee0d93d82ce7e579c708e60
# 5ee0d7bf82ce7e579c708e4b
# 5ee0da3282ce7e579c708e69
# 5ee0daa682ce7e579c708e6d

# %%
#First we get the json item for each catalog number.  
#We need to check to make sure the order of the catalog items is the same as the files we want to upload
#Let's make a list of catalog numbers and 

arrayName = []
for i in range(len(children)):
 childItem_json = sb.get_item(children[i])
 for item in childItem_json['files']:
  fileEXT = item['name'].split('.', 1)[-1]
  if fileEXT == 'xml':
   arrayName.append(item['name']) 
   #print (fileEXT)
    
for i in range(len(children)): 
 print ('Name Index ' + str(i) + ': ' + arrayName[i])
 print ('Cat Number ' + str(i) + ': ' + children[i])
 #print (xmlFileNameArray[i] + '\n')
# Out:
# Name Index 0: USA-Colorado-Silverton_Caldera-2019-AMTAG04.xml
# Cat Number 0: 5ee0d68b82ce7e579c708e36
# Name Index 1: USA-Colorado-Silverton_Caldera-2019-AMTMB06.xml
# Cat Number 1: 5ee0d9fa82ce7e579c708e67
# Name Index 2: USA-Colorado-Silverton_Caldera-2019-AMTSF04.xml
# Cat Number 2: 5ee0dcff82ce7e579c708e83
# Name Index 3: USA-Colorado-Silverton_Caldera-2019-AMTAG03.xml
# Cat Number 3: 5ee0d4ba82ce7e579c708e31
# Name Index 4: USA-Colorado-Silverton_Caldera-2019-AMTAG02.xml
# Cat Number 4: 5ee0d3c782ce7e579c708e2e
# Name Index 5: USA-Colorado-Silverton_Caldera-2019-AMTAG06.xml
# Cat Number 5: 5ee0d72c82ce7e579c708e45
# Name Index 6: USA-Colorado-Silverton_Caldera-2019-AMTKM01.xml
# Cat Number 6: 5ee0d86a82ce7e579c708e55
# Name Index 7: USA-Colorado-Silverton_Caldera-2019-AMTSF01.xml
# Cat Number 7: 5ee0db6182ce7e579c708e74
# Name Index 8: USA-Colorado-Silverton_Caldera-2019-AMTEG08.xml
# Cat Number 8: 5ee0d82782ce7e579c708e51
# Name Index 9: USA-Colorado-Silverton_Caldera-2019-AMTSF05.xml
# Cat Number 9: 5ee0dd4d82ce7e579c708e85
# Name Index 10: USA-Colorado-Silverton_Caldera-2019-AMTEG06.xml
# Cat Number 10: 5ee0d77f82ce7e579c708e48
# Name Index 11: USA-Colorado-Silverton_Caldera-2019-AMTMB08.xml
# Cat Number 11: 5ee0da7282ce7e579c708e6b
# Name Index 12: USA-Colorado-Silverton_Caldera-2019-AMTMC02.xml
# Cat Number 12: 5ee0db2082ce7e579c708e71
# Name Index 13: USA-Colorado-Silverton_Caldera-2019-AMTSF06.xml
# Cat Number 13: 5ee0dd8582ce7e579c708e87
# Name Index 14: USA-Colorado-Silverton_Caldera-2019-AMTKM03.xml
# Cat Number 14: 5ee0d8f582ce7e579c708e5e
# Name Index 15: USA-Colorado-Silverton_Caldera-2019-AMTMC01.xml
# Cat Number 15: 5ee0daea82ce7e579c708e6f
# Name Index 16: USA-Colorado-Silverton_Caldera-2019-AMTSF03.xml
# Cat Number 16: 5ee0dcc382ce7e579c708e7f
# Name Index 17: USA-Colorado-Silverton_Caldera-2019-AMTAG05.xml
# Cat Number 17: 5ee0d6d182ce7e579c708e39
# Name Index 18: USA-Colorado-Silverton_Caldera-2019-AMTKM05.xml
# Cat Number 18: 5ee0d97e82ce7e579c708e62
# Name Index 19: USA-Colorado-Silverton_Caldera-2019-AMTAG01.xml
# Cat Number 19: 5ee0d2d482ce7e579c708e28
# Name Index 20: USA-Colorado-Silverton_Caldera-2019-AMTKM02.xml
# Cat Number 20: 5ee0d8b882ce7e579c708e5a
# Name Index 21: USA-Colorado-Silverton_Caldera-2019-AMTSF02.xml
# Cat Number 21: 5ee0dc8a82ce7e579c708e7a
# Name Index 22: USA-Colorado-Silverton_Caldera-2019-AMTKM04.xml
# Cat Number 22: 5ee0d93d82ce7e579c708e60
# Name Index 23: USA-Colorado-Silverton_Caldera-2019-AMTEG07.xml
# Cat Number 23: 5ee0d7bf82ce7e579c708e4b
# Name Index 24: USA-Colorado-Silverton_Caldera-2019-AMTMB07.xml
# Cat Number 24: 5ee0da3282ce7e579c708e69
# Name Index 25: USA-Colorado-Silverton_Caldera-2019-AMTMB09.xml
# Cat Number 25: 5ee0daa682ce7e579c708e6d

# %%
#Now we loop through our name array and if it matches use tha name index for that child replace
for i in range(len(children)):
 #print (arrayName[i])
 for j in range(len(xmlFileNameArray)):
  #print ('\t' + xmlFileNameArray[j])
  if xmlFileNameArray[j] == arrayName[i]:
    #here is were we would replace a value - !!!Uncomment below to activate!!!
    childItem_json = sb.get_item(children[i])
    sb.replace_file(xmlListFullPath[j], childItem_json)
    print ('ScienceBase XML Replaced with ' + xmlListFullPath[j])   
    print ('\tFile Name:' + xmlFileNameArray[j] + '\n\tChild Name: ' + arrayName[i] + '\n\tCatalog Number: ' + children[i] + '\n\n')
# Out:
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG04.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTAG04.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTAG04.xml
# 	Catalog Number: 5ee0d68b82ce7e579c708e36
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMB06.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTMB06.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTMB06.xml
# 	Catalog Number: 5ee0d9fa82ce7e579c708e67
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF04.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTSF04.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTSF04.xml
# 	Catalog Number: 5ee0dcff82ce7e579c708e83
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG03.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTAG03.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTAG03.xml
# 	Catalog Number: 5ee0d4ba82ce7e579c708e31
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG02.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTAG02.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTAG02.xml
# 	Catalog Number: 5ee0d3c782ce7e579c708e2e
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG06.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTAG06.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTAG06.xml
# 	Catalog Number: 5ee0d72c82ce7e579c708e45
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTKM01.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTKM01.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTKM01.xml
# 	Catalog Number: 5ee0d86a82ce7e579c708e55
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF01.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTSF01.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTSF01.xml
# 	Catalog Number: 5ee0db6182ce7e579c708e74
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTEG08.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTEG08.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTEG08.xml
# 	Catalog Number: 5ee0d82782ce7e579c708e51
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF05.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTSF05.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTSF05.xml
# 	Catalog Number: 5ee0dd4d82ce7e579c708e85
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTEG06.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTEG06.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTEG06.xml
# 	Catalog Number: 5ee0d77f82ce7e579c708e48
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMB08.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTMB08.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTMB08.xml
# 	Catalog Number: 5ee0da7282ce7e579c708e6b
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMC02.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTMC02.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTMC02.xml
# 	Catalog Number: 5ee0db2082ce7e579c708e71
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF06.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTSF06.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTSF06.xml
# 	Catalog Number: 5ee0dd8582ce7e579c708e87
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTKM03.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTKM03.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTKM03.xml
# 	Catalog Number: 5ee0d8f582ce7e579c708e5e
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMC01.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTMC01.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTMC01.xml
# 	Catalog Number: 5ee0daea82ce7e579c708e6f
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF03.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTSF03.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTSF03.xml
# 	Catalog Number: 5ee0dcc382ce7e579c708e7f
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG05.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTAG05.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTAG05.xml
# 	Catalog Number: 5ee0d6d182ce7e579c708e39
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTKM05.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTKM05.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTKM05.xml
# 	Catalog Number: 5ee0d97e82ce7e579c708e62
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTAG01.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTAG01.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTAG01.xml
# 	Catalog Number: 5ee0d2d482ce7e579c708e28
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTKM02.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTKM02.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTKM02.xml
# 	Catalog Number: 5ee0d8b882ce7e579c708e5a
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTSF02.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTSF02.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTSF02.xml
# 	Catalog Number: 5ee0dc8a82ce7e579c708e7a
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTKM04.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTKM04.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTKM04.xml
# 	Catalog Number: 5ee0d93d82ce7e579c708e60
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTEG07.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTEG07.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTEG07.xml
# 	Catalog Number: 5ee0d7bf82ce7e579c708e4b
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMB07.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTMB07.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTMB07.xml
# 	Catalog Number: 5ee0da3282ce7e579c708e69
#
#
# ScienceBase XML Replaced with C:\CurrentWork\DataReleases\SilvertonAMT_SB-Batch-Upload-Test\Metadata\USA-Colorado-Silverton_Caldera-2019-AMTMB09.xml
# 	File Name:USA-Colorado-Silverton_Caldera-2019-AMTMB09.xml
# 	Child Name: USA-Colorado-Silverton_Caldera-2019-AMTMB09.xml
# 	Catalog Number: 5ee0daa682ce7e579c708e6d
